# %% [markdown]
# <a href="https://colab.research.google.com/github/HuifeixinChen/LLaVA-/blob/main/LLaVA_7b_8bit_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone -b 5GB https://github.com/camenduru/LLaVA
# %cd /content/LLaVA

# !pip install -q transformers==4.36.2
# !pip install ninja
# !pip install flash-attn --no-build-isolation

# !pip install -e .

# !python -m llava.serve.cli \
#     --model-path 4bit/llava-v1.5-7b-5GB \
#     --image-file "https://llava-vl.github.io/static/images/view.jpg" \
#     --load-8bit
# Out:
# /content
# Cloning into 'LLaVA'...
# remote: Enumerating objects: 1960, done.
# remote: Total 1960 (delta 0), reused 0 (delta 0), pack-reused 1960 (from 1)
# Receiving objects: 100% (1960/1960), 13.60 MiB | 17.43 MiB/s, done.
# Resolving deltas: 100% (1173/1173), done.
# /content/LLaVA
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llava 1.1.0 requires transformers==4.31.0, but you have transformers 4.36.2 which is incompatible.
# sentence-transformers 4.1.0 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.36.2 which is incompatible.
# Requirement already satisfied: ninja in /usr/local/lib/python3.11/dist-packages (1.11.1.4)
# Requirement already satisfied: flash-attn in /usr/local/lib/python3.11/dist-packages (2.7.4.post1)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from flash-attn) (2.6.0+cu124)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from flash-attn) (0.6.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->flash-attn) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->flash-attn) (3.0.2)
# Obtaining file:///content/LLaVA
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from llava==1.1.0) (0.6.1)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.11/dist-packages (from llava==1.1.0) (0.115.12)
# Requirement already satisfied: gradio==3.35.2 in /usr/local/lib/python3.11/dist-packages (from llava==1.1.0) (3.35.2)
# Requirement already satisfied: markdown2[all] in /usr/local/lib/python3.11/dist-packages (from llava==1.1.0) (2.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from llava==1.1.0) (2.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from llava==1.1.0) (2.32.3)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from llava==1.1.0) (0.1.99)
# Requirement already satisfied: tokenizers>=0.12.1 in /usr/local/lib/python3.11/dist-packages (from llava==1.1.0) (0.15.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from llava==1.1.0) (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from llava==1.1.0) (0.21.0+cu124)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.11/dist-packages (from llava==1.1.0) (0.34.3)
# Requirement already satisfied: wandb in /usr/local/lib/python3.11/dist-packages (from llava==1.1.0) (0.19.11)
# Requirement already satisfied: shortuuid in /usr/local/lib/python3.11/dist-packages (from llava==1.1.0) (1.0.13)
# Requirement already satisfied: httpx==0.24.0 in /usr/local/lib/python3.11/dist-packages (from llava==1.1.0) (0.24.0)
# Requirement already satisfied: deepspeed==0.9.5 in /usr/local/lib/python3.11/dist-packages (from llava==1.1.0) (0.9.5)
# Requirement already satisfied: peft==0.4.0 in /usr/local/lib/python3.11/dist-packages (from llava==1.1.0) (0.4.0)
# Collecting transformers==4.31.0 (from llava==1.1.0)
#   Using cached transformers-4.31.0-py3-none-any.whl.metadata (116 kB)
# Requirement already satisfied: accelerate==0.21.0 in /usr/local/lib/python3.11/dist-packages (from llava==1.1.0) (0.21.0)
# Requirement already satisfied: bitsandbytes==0.41.0 in /usr/local/lib/python3.11/dist-packages (from llava==1.1.0) (0.41.0)
# Requirement already satisfied: scikit-learn==1.2.2 in /usr/local/lib/python3.11/dist-packages (from llava==1.1.0) (1.2.2)
# Requirement already satisfied: einops-exts==0.0.4 in /usr/local/lib/python3.11/dist-packages (from llava==1.1.0) (0.0.4)
# Requirement already satisfied: timm==0.6.13 in /usr/local/lib/python3.11/dist-packages (from llava==1.1.0) (0.6.13)
# Requirement already satisfied: gradio_client==0.2.9 in /usr/local/lib/python3.11/dist-packages (from llava==1.1.0) (0.2.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from accelerate==0.21.0->llava==1.1.0) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate==0.21.0->llava==1.1.0) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from accelerate==0.21.0->llava==1.1.0) (6.0.2)
# Requirement already satisfied: hjson in /usr/local/lib/python3.11/dist-packages (from deepspeed==0.9.5->llava==1.1.0) (3.1.0)
# Requirement already satisfied: ninja in /usr/local/lib/python3.11/dist-packages (from deepspeed==0.9.5->llava==1.1.0) (1.11.1.4)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from deepspeed==0.9.5->llava==1.1.0) (9.0.0)
# Requirement already satisfied: pydantic<2.0.0 in /usr/local/lib/python3.11/dist-packages (from deepspeed==0.9.5->llava==1.1.0) (1.10.22)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from deepspeed==0.9.5->llava==1.1.0) (4.67.1)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.11/dist-packages (from gradio==3.35.2->llava==1.1.0) (24.1.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from gradio==3.35.2->llava==1.1.0) (3.11.15)
# Requirement already satisfied: altair>=4.2.0 in /usr/local/lib/python3.11/dist-packages (from gradio==3.35.2->llava==1.1.0) (5.5.0)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.11/dist-packages (from gradio==3.35.2->llava==1.1.0) (0.6.0)
# Requirement already satisfied: huggingface-hub>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from gradio==3.35.2->llava==1.1.0) (0.32.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from gradio==3.35.2->llava==1.1.0) (3.1.6)
# Requirement already satisfied: markdown-it-py>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py[linkify]>=2.0.0->gradio==3.35.2->llava==1.1.0) (2.2.0)
# Requirement already satisfied: markupsafe in /usr/local/lib/python3.11/dist-packages (from gradio==3.35.2->llava==1.1.0) (3.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from gradio==3.35.2->llava==1.1.0) (3.10.0)
# Requirement already satisfied: mdit-py-plugins<=0.3.3 in /usr/local/lib/python3.11/dist-packages (from gradio==3.35.2->llava==1.1.0) (0.3.3)
# Requirement already satisfied: orjson in /usr/local/lib/python3.11/dist-packages (from gradio==3.35.2->llava==1.1.0) (3.10.18)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from gradio==3.35.2->llava==1.1.0) (2.2.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from gradio==3.35.2->llava==1.1.0) (11.2.1)
# Requirement already satisfied: pydub in /usr/local/lib/python3.11/dist-packages (from gradio==3.35.2->llava==1.1.0) (0.25.1)
# Requirement already satisfied: pygments>=2.12.0 in /usr/local/lib/python3.11/dist-packages (from gradio==3.35.2->llava==1.1.0) (2.19.1)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.11/dist-packages (from gradio==3.35.2->llava==1.1.0) (0.0.20)
# Requirement already satisfied: semantic-version in /usr/local/lib/python3.11/dist-packages (from gradio==3.35.2->llava==1.1.0) (2.10.0)
# Requirement already satisfied: websockets>=10.0 in /usr/local/lib/python3.11/dist-packages (from gradio==3.35.2->llava==1.1.0) (15.0.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from gradio_client==0.2.9->llava==1.1.0) (2025.3.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from gradio_client==0.2.9->llava==1.1.0) (4.14.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx==0.24.0->llava==1.1.0) (2025.4.26)
# Requirement already satisfied: httpcore<0.18.0,>=0.15.0 in /usr/local/lib/python3.11/dist-packages (from httpx==0.24.0->llava==1.1.0) (0.17.3)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx==0.24.0->llava==1.1.0) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from httpx==0.24.0->llava==1.1.0) (1.3.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from peft==0.4.0->llava==1.1.0) (0.5.3)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.2.2->llava==1.1.0) (1.15.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.2.2->llava==1.1.0) (1.5.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.2.2->llava==1.1.0) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.31.0->llava==1.1.0) (3.18.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.31.0->llava==1.1.0) (2024.11.6)
# Collecting tokenizers>=0.12.1 (from llava==1.1.0)
#   Using cached tokenizers-0.13.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->llava==1.1.0) (3.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->llava==1.1.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->llava==1.1.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->llava==1.1.0) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->llava==1.1.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch->llava==1.1.0) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch->llava==1.1.0) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch->llava==1.1.0) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch->llava==1.1.0) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch->llava==1.1.0) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->llava==1.1.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->llava==1.1.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->llava==1.1.0) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->llava==1.1.0) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->llava==1.1.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->llava==1.1.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->llava==1.1.0) (1.3.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/dist-packages (from uvicorn->llava==1.1.0) (8.2.1)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.11/dist-packages (from uvicorn->llava==1.1.0) (0.14.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from fastapi->llava==1.1.0) (0.46.2)
# Requirement already satisfied: wavedrom in /usr/local/lib/python3.11/dist-packages (from markdown2[all]->llava==1.1.0) (2.0.3.post3)
# Requirement already satisfied: latex2mathml in /usr/local/lib/python3.11/dist-packages (from markdown2[all]->llava==1.1.0) (3.78.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->llava==1.1.0) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->llava==1.1.0) (2.4.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from wandb->llava==1.1.0) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb->llava==1.1.0) (3.1.44)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from wandb->llava==1.1.0) (4.3.8)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.11/dist-packages (from wandb->llava==1.1.0) (5.29.5)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb->llava==1.1.0) (2.29.1)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.11/dist-packages (from wandb->llava==1.1.0) (1.3.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from wandb->llava==1.1.0) (75.2.0)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.11/dist-packages (from altair>=4.2.0->gradio==3.35.2->llava==1.1.0) (4.24.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.11/dist-packages (from altair>=4.2.0->gradio==3.35.2->llava==1.1.0) (1.41.0)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from docker-pycreds>=0.4.0->wandb->llava==1.1.0) (1.17.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb->llava==1.1.0) (4.0.12)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.11/dist-packages (from httpcore<0.18.0,>=0.15.0->httpx==0.24.0->llava==1.1.0) (4.9.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.14.0->gradio==3.35.2->llava==1.1.0) (1.1.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.0.0->markdown-it-py[linkify]>=2.0.0->gradio==3.35.2->llava==1.1.0) (0.1.2)
# Requirement already satisfied: linkify-it-py<3,>=1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py[linkify]>=2.0.0->gradio==3.35.2->llava==1.1.0) (2.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->gradio==3.35.2->llava==1.1.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->gradio==3.35.2->llava==1.1.0) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->gradio==3.35.2->llava==1.1.0) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->gradio==3.35.2->llava==1.1.0) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->gradio==3.35.2->llava==1.1.0) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->gradio==3.35.2->llava==1.1.0) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->gradio==3.35.2->llava==1.1.0) (1.20.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->gradio==3.35.2->llava==1.1.0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->gradio==3.35.2->llava==1.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->gradio==3.35.2->llava==1.1.0) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->gradio==3.35.2->llava==1.1.0) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->gradio==3.35.2->llava==1.1.0) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->gradio==3.35.2->llava==1.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->gradio==3.35.2->llava==1.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->gradio==3.35.2->llava==1.1.0) (2025.2)
# Requirement already satisfied: svgwrite in /usr/local/lib/python3.11/dist-packages (from wavedrom->markdown2[all]->llava==1.1.0) (1.4.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->llava==1.1.0) (5.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair>=4.2.0->gradio==3.35.2->llava==1.1.0) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair>=4.2.0->gradio==3.35.2->llava==1.1.0) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair>=4.2.0->gradio==3.35.2->llava==1.1.0) (0.25.1)
# Requirement already satisfied: uc-micro-py in /usr/local/lib/python3.11/dist-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify]>=2.0.0->gradio==3.35.2->llava==1.1.0) (1.0.3)
# Using cached transformers-4.31.0-py3-none-any.whl (7.4 MB)
# Using cached tokenizers-0.13.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
# Building wheels for collected packages: llava
#   Building editable for llava (pyproject.toml) ... done
#   Created wheel for llava: filename=llava-1.1.0-0.editable-py3-none-any.whl size=14900 sha256=c4eb602989b03ec4f1a0c221be23369e2830c7ba324e826675b54788e16c4064
#   Stored in directory: /tmp/pip-ephem-wheel-cache-e1bmlbj0/wheels/55/a1/dd/fc37ed4f847b25c140c977a5e08209dfbe50be519f62fb82a9
# Successfully built llava
# Installing collected packages: tokenizers, transformers, llava
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.15.2
#     Uninstalling tokenizers-0.15.2:
#       Successfully uninstalled tokenizers-0.15.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.36.2
#     Uninstalling transformers-4.36.2:
#       Successfully uninstalled transformers-4.36.2
#   Attempting uninstall: llava
#     Found existing installation: llava 1.1.0
#     Uninstalling llava-1.1.0:
#       Successfully uninstalled llava-1.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 4.1.0 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.31.0 which is incompatible.
# Successfully installed llava-1.1.0 tokenizers-0.13.3 transformers-4.31.0

# %%
# 官方DEMO微调数据下载
# !wget https://huggingface.co/datasets/liuhaotian/llava-instruct-150k/resolve/main/llava_instruct_150k.json
# !mkdir images
# 下载几张图片到 images/ 作为DEMO
# !wget https://llava-vl.github.io/static/images/view.jpg -O images/view.jpg
# Out:
# --2025-06-14 18:03:18--  https://huggingface.co/datasets/liuhaotian/llava-instruct-150k/resolve/main/llava_instruct_150k.json
# Resolving huggingface.co (huggingface.co)... 13.35.202.97, 13.35.202.34, 13.35.202.40, ...
# Connecting to huggingface.co (huggingface.co)|13.35.202.97|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: /datasets/liuhaotian/LLaVA-Instruct-150K/resolve/main/llava_instruct_150k.json [following]
# --2025-06-14 18:03:18--  https://huggingface.co/datasets/liuhaotian/LLaVA-Instruct-150K/resolve/main/llava_instruct_150k.json
# Reusing existing connection to huggingface.co:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.hf.co/repos/4d/41/4d41ea1e2709f0e68e9e361e4218192b9620c5a3f2cb8055bc625942b6cd3039/6b68bc5ca2bfd8a71119af0e8454929668ccda6a334955ccc95d114fc8d082fa?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27llava_instruct_150k.json%3B+filename%3D%22llava_instruct_150k.json%22%3B&response-content-type=application%2Fjson&Expires=1749927798&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qJnJlc3BvbnNlLWNvbnRlbnQtdHlwZT0qIn1dfQ__&Signature=rmTIewMMJD3wwrOYkENgK5y5gXQavLnGRV-eJen-8tQzU-FdByCukyaAk1a5y3XJ3gCfRzeNxRnlBRHaENcKYLB2yJ%7EmrQu7%7EQHOHt8suQqbsWyb78RJ63yWhX2BavZU09x7ckJW10F522-Wg2FO-U6nxRFbAutCCMAoi5b7RFNWjeMGuNx9K1VqJnHYs8unEMtM8BIU3PaKvkBQBrfbBm6-g%7EWfTy%7Eibbmqrsa2fPW1RmBsYqoq8Y2JnJXiXJEc7Gs57bQF36YIao0-iknJufipEHVa6sbkCCKqknzLPn71bpUHkTN6jiiIT6b0MIUkD21HW1duuUaT4wQ87eMNNQ__&Key-Pair-Id=K3RPWS32NSSJCE [following]
# --2025-06-14 18:03:18--  https://cdn-lfs.hf.co/repos/4d/41/4d41ea1e2709f0e68e9e361e4218192b9620c5a3f2cb8055bc625942b6cd3039/6b68bc5ca2bfd8a71119af0e8454929668ccda6a334955ccc95d114fc8d082fa?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27llava_instruct_150k.json%3B+filename%3D%22llava_instruct_150k.json%22%3B&response-content-type=application%2Fjson&Expires=1749927798&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qJnJlc3BvbnNlLWNvbnRlbnQtdHlwZT0qIn1dfQ__&Signature=rmTIewMMJD3wwrOYkENgK5y5gXQavLnGRV-eJen-8tQzU-FdByCukyaAk1a5y3XJ3gCfRzeNxRnlBRHaENcKYLB2yJ%7EmrQu7%7EQHOHt8suQqbsWyb78RJ63yWhX2BavZU09x7ckJW10F522-Wg2FO-U6nxRFbAutCCMAoi5b7RFNWjeMGuNx9K1VqJnHYs8unEMtM8BIU3PaKvkBQBrfbBm6-g%7EWfTy%7Eibbmqrsa2fPW1RmBsYqoq8Y2JnJXiXJEc7Gs57bQF36YIao0-iknJufipEHVa6sbkCCKqknzLPn71bpUHkTN6jiiIT6b0MIUkD21HW1duuUaT4wQ87eMNNQ__&Key-Pair-Id=K3RPWS32NSSJCE
# Resolving cdn-lfs.hf.co (cdn-lfs.hf.co)... 3.170.229.28, 3.170.229.105, 3.170.229.125, ...
# Connecting to cdn-lfs.hf.co (cdn-lfs.hf.co)|3.170.229.28|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 228941895 (218M) [application/json]
# Saving to: ‘llava_instruct_150k.json’
#
# llava_instruct_150k 100%[===================>] 218.34M  24.0MB/s    in 9.2s
#
# 2025-06-14 18:03:28 (23.7 MB/s) - ‘llava_instruct_150k.json’ saved [228941895/228941895]
#
# mkdir: cannot create directory ‘images’: File exists
# --2025-06-14 18:03:28--  https://llava-vl.github.io/static/images/view.jpg
# Resolving llava-vl.github.io (llava-vl.github.io)... 185.199.108.153, 185.199.109.153, 185.199.110.153, ...
# Connecting to llava-vl.github.io (llava-vl.github.io)|185.199.108.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 95499 (93K) [image/jpeg]
# Saving to: ‘images/view.jpg’
#
# images/view.jpg     100%[===================>]  93.26K  --.-KB/s    in 0.002s
#
# 2025-06-14 18:03:28 (38.4 MB/s) - ‘images/view.jpg’ saved [95499/95499]

# %%
import threading
import subprocess
command = [
    'python3', '-m', 'llava.serve.model_worker',
    '--host', '0.0.0.0',
    '--controller', 'http://localhost:10000',
    '--port', '40000',
    '--worker', 'http://localhost:40000',
    '--model-path', '4bit/llava-v1.5-7b-5GB',
    '--load-8bit'
]
threading.Thread(target=lambda: subprocess.run(command, check=True, shell=False), daemon=True).start()

# %%
# !python3 -m llava.serve.gradio_web_server --controller http://localhost:10000 --model-list-mode reload --share
